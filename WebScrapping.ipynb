# %% [markdown]
# <a href="https://colab.research.google.com/github/Annapoornaaradhya/Xorstack/blob/main/WebScrapping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
from bs4 import BeautifulSoup
url = "https://stackoverflow.com/questions/tagged/python?tab=newest"
headers = {
    "User-Agent": "Mozilla/5.0"
}
response = requests.get(url, headers=headers)
soup = BeautifulSoup(response.text, "html.parser")
questions = soup.select("div.s-post-summary h3 a.s-link")
for i, q in enumerate(questions, start=1):
    print(f"{i}. {q.get_text(strip=True)}")
# Out:
# 1. What are the recommended ways to work with files and directories in Python?
# 2. PySpark .show() fails with “Python worker exited unexpectedly” on Windows (Python 3.14)
# 3. What are the best resources for learning for a new software dev?
# 4. Pygame 2D image animations rendering in the wrong way
# 5. Can I access my Apple Music library via API from a generic Python script?
# 6. What's wrong with my Syndyne-Synchrone (comet tail) PA output?
# 7. XGBoost GPU regression fails at predict time with Check failed: dmat->Device() when training with tree_method='hist' and device='cuda'
# 8. Finding unique 1D arrays and corresponding 2D index pairs in 3D array (with numpy)
# 9. Tool to autocomplete `python -m` module calls for the Fish shell
# 10. ThreadedDepthCacheManager ignoring the limit I put at the order book
# 11. Python casting string without knowing its type [duplicate]
# 12. Is there a way to get selenium to connect to an edge browser for old IE sites?
# 13. Opencl Dot product kernel fails on specific data
# 14. How do I get my program to generate and print intermediary temporary arrays in a divide-and-conquer binary search?
# 15. Passing a matrix from python to R through rpy2 [closed]
# 16. Global AsyncClient Reuse Best Practices
# 17. Pydantic V1 functionality isn't compatible with Python 3.14
# 18. Why am I getting _ tkinter.tclerror:? [closed]
# 19. sklearn's FactorAnalysis varimax orthogonal rotation increases correlation of factors
# 20. Fastapi.StreamingResponse: OSError: incomplete frame
# 21. What security measures to implement when using React JS and Python Backend with Rest API
# 22. Tkinter Program [closed]
# 23. Sending update from the server to the client in Python/JavaScript [closed]
# 24. Selenium opening browser very slowly on Mac
# 25. How to fix the Python code to avoid a pycodestyle error E262 (inline comment should start with '# ')?
# 26. How to have user log in once and then reuse the same session over different python-playwright browser tests?
# 27. Whitespace after '{' for set comprehension in f-strings [duplicate]
# 28. nvim-dap debug using external terminal
# 29. Importing local packages in PyCharm displays an an error, but works
# 30. Is it possible to use a shebang to force a certain Python 3 version (e.g. python3.12 instead of python3)?
# 31. How do you solve "Unable to import 'cx_freeze'" - E0401:import-error?
# 32. Cropping a graph in Python
# 33. Python Multiplication of Two Arrays that May or May Not Have Same Shape
# 34. Add context info without modifying root logger
# 35. I get an unbalanced diagonal matrix when trying to find the eigenvalues [closed]
# 36. Troubling Scope Issues Within Definition [closed]
# 37. pynetdicom C-GET fails when multiple transfer syntaxes are requested for compressed images
# 38. RL agent fails to converge/improve average reward in Gymnasium FlappyBird-v0 Tabular Q-Learning
# 39. Learning Machine Learning and AI
# 40. Why am I getting a stack trace with no exception in the message section when I run my selenium crawler
# 41. Best Way To Handle a Async Celery Task
# 42. Django archive user if clicked for detail page view an error appears
# 43. Get this file updated on Google Colab [closed]
# 44. Plotly Express facets show no lines when setting x-axis range and custom tick labels
# 45. JP2 image metadata copying for cv2 treatment
# 46. Can Python install packages on a shorter path on Windows?
# 47. Open selected file with application? Like opening a .blend file from the file explorer
# 48. Mendeley Data API Issue Report [closed]
# 49. ChainedAssignmentError when adding a conditional to a pandas dataframe
# 50. Tokenizer configuration - MLX

# %%
import requests
from bs4 import BeautifulSoup
url = "https://stackoverflow.com/questions/tagged/python?tab=newest"
headers = {
    "User-Agent": "Mozilla/5.0"
}
response = requests.get(url, headers=headers)
soup = BeautifulSoup(response.text, "html.parser")
questions = soup.select("div.s-post-summary")
for i, q in enumerate(questions, start=1):
    title_tag = q.select_one("h3 a.s-link")
    desc_tag = q.select_one("div.s-post-summary--content-excerpt")
    title = title_tag.get_text(strip=True) if title_tag else "No title"
    description = desc_tag.get_text(strip=True) if desc_tag else "No description"
    print(f"{i}. {title}")
    print(f"   {description}\n")
# Out:
# 1. Aide pour un jeu python [closed]
#    Bonjour,
# Je suis une élève en première et nous devons créer notre premier jeu sur Python. Mon équipe et moi avons déjà créer la carte grâce au logiciel Tiles et nous avons tenté de rajouter les murs ...
#
# 2. PySpark .show() fails with “Python worker exited unexpectedly” on Windows (Python 3.14)
#    Body
# I am facing a PySpark error on Windows while calling .show() on a DataFrame. The job fails with a Python worker crash.
# Environment
#
# OS: Windows 10
#
# Spark: Apache Spark (PySpark)
#
# IDE: VS Code
#
# ...
#
# 3. What are the best resources for learning for a new software dev?
#    I am a new software developer and want to learn about developing software and on how to write efficient code, and want to grow, what are the best resources and how should one grow in learning in this ...
#
# 4. Pygame 2D image animations rendering in the wrong way
#    I have been making a 2D platform game which has a melee attacking system. I have only one attacking animation frame image which is flipped based on the self.direction flag.
# The main issue is that when ...
#
# 5. Can I access my Apple Music library via API from a generic Python script?
#    I'd like to write some native Python code to create some playlists in my Apple Music account.  I've moved away from Amazon Music, I dumped my old playlists from that environment into text files, I can ...
#
# 6. What's wrong with my Syndyne-Synchrone (comet tail) PA output?
#    Been investigating the 3I/Atlas (or C/2025 N1) rabbit hole. Of note is its ''anti-tail'' with some arguing it isn't a perspective effect. So, to test this I'm trying to use a ''syndyne-synchrone'' ...
#
# 7. XGBoost GPU regression fails at predict time with Check failed: dmat->Device() when training with tree_method='hist' and device='cuda'
#    I’m training an XGBRegressor on GPU and it fits successfully, but predict() fails depending on whether the input at prediction time is a NumPy array vs a pandas DataFrame (or whether I move between ...
#
# 8. Finding unique 1D arrays and corresponding 2D index pairs in 3D array (with numpy)
#    I have a 3D numerical array X, of shape=(N,N,6); and a 2D logical array mask, of shape=(N,N). I would like to find all unique 1D subarrays (length=6, along  axis=2) of X, searching over the first two ...
#
# 9. Tool to autocomplete `python -m` module calls for the Fish shell
#    Directly inspired from Command-line autocompletion for python -m module. Is there any extension to Fish shell that allows TAB-like autocomplete for python -m calls? In my case I only wish for it to ...
#
# 10. ThreadedDepthCacheManager ignoring the limit I put at the order book
#    I'm using ThreadedDepthCacheManager in python-binance to get the orders from the book, and at the start_depth_cache method I'm setting the limit to only 2 depths in the order book. Still, for each ...
#
# 11. Python casting string without knowing its type [duplicate]
#    If I have a value that was previously statically turned into a string constant and stored (so it could be of any type, e.g. "5", "1.34", "hello", "[1, 4, 5]"), ...
#
# 12. Is there a way to get selenium to connect to an edge browser for old IE sites?
#    I have my old python script for some work intranet sites we still have not upgraded that run in IE compatibility within edge. I changed it a bit to update since IE is no longer available after os ...
#
# 13. Opencl Dot product kernel fails on specific data
#    I have a opencl kernel that performs a dot product multiplication. When I run it on a random numpy array created by rng.random, it gives a percent error compared to numpy of -0.011454765, but when I ...
#
# 14. How do I get my program to generate and print intermediary temporary arrays in a divide-and-conquer binary search?
#    I'm a beginner coder taking an introductory comp science course and I'm trying to figure out how to get a divide-and-conquer binary search to print the arrays between the main array and the final ...
#
# 15. Passing a matrix from python to R through rpy2 [closed]
#    I am trying to find out how to pass a matrix from python into R through rpy2 for further processing into the R script and then get the resulting value back to python. Everywhere I 've looked I see how ...
#
# 16. Global AsyncClient Reuse Best Practices
#    I'm wondering what the best practice for a global httpx GlobalClient is in Python 3.14. generally it's best to have a single global event loop, but what if I need more parallelism or to not block with ...
#
# 17. Pydantic V1 functionality isn't compatible with Python 3.14
#    I have an error when importing replicate lib in my Python 3.14 project
# D:\Api\proj\.venv\Lib\site-packages\replicate\resource.py:5: UserWarning: Core Pydantic V1 functionality isn't compatible with ...
#
# 18. Why am I getting _ tkinter.tclerror:? [closed]
#    Tkinter program was running perfectly but suddenly started showing the following error whenever I ran it.
# Tkinter Program Showing
# Traceback (most recent call last):
#   File "c:\Users\allen\...
#
# 19. sklearn's FactorAnalysis varimax orthogonal rotation increases correlation of factors
#    I'm using Scikit-Learn's FactorAnalysis in an application that relies on the assumption that the factors are uncorrelated. It would be great to have more interpretable factors, and an orthogonal ...
#
# 20. Fastapi.StreamingResponse: OSError: incomplete frame
#    I am writing FastAPI service. I received .zstd archive from S3. I have to return decompressed json data from the archive. I read about fastapi.StreamingResponse
# My code
# import os
# import cramjam
#
# from ...
#
# 21. What security measures to implement when using React JS and Python Backend with Rest API
#    I am building a React + python(Fast API) application where these 2 applications are connected via Rest API. My question is if anyone who knows the ENDPOINT , and params that needs to be sent, Anyone ...
#
# 22. Tkinter Program [closed]
#    My Tkinter program was running perfectly but suddenly started showing the following error whenever I ran it.
# Tkinter Program Showing
# Error: _tkinter.TclError: wrong
# args: should be ".!treeview
# ...
#
# 23. Sending update from the server to the client in Python/JavaScript [closed]
#    I built a website with a Python backend that generates data and then sends it to the frontend (JavaScript) as a file. The issue is that the generation process can take a long time (up to 10 minutes), ...
#
# 24. Selenium opening browser very slowly on Mac
#    Even with this simple code, Selenium takes about 5-10 seconds to open the browser. I used another machine (window) to run the same code and it takes less than 1 second to open it.
# I've tried changing ...
#
# 25. How to fix the Python code to avoid a pycodestyle error E262 (inline comment should start with '# ')?
#    I have something like this:
# MAP = {
#     2: "aaa",   #  This is aaa
#     4: "b",     #  This is some b
#     7: "cc"     #  See?
# }
#
# and I run:
# pycodestyle --ignore=E203,W503 -...
#
# 26. How to have user log in once and then reuse the same session over different python-playwright browser tests?
#    Using
# dependencies = [
#   "pytest>=9.0.2",
#   "pytest-playwright",
# ]
#
# in a Python application I am setting a a browser end to end test.
# I have defined custom markers:
# [tool.pytest....
#
# 27. Whitespace after '{' for set comprehension in f-strings [duplicate]
#    What is the correct way to define set/dictionary comprehension in f-strings, so that flake8 does not complain? Currently I get the following errors:
# echo 'f"{ {k for k in []} }"' | flake8 -
# ...
#
# 28. nvim-dap debug using external terminal
#    I want to launch my debug adapters from an external terminal because I'm sick and tired of always adapting the launch.json or dap-configurations when I could just alter the command directly from the ...
#
# 29. Importing local packages in PyCharm displays an an error, but works
#    I have a Python package locally installed via 'pip install -e .' I can call things from that library in other projects, everything works OK.
# I am working with PyCharm, and each time I start with that ...
#
# 30. Is it possible to use a shebang to force a certain Python 3 version (e.g. python3.12 instead of python3)?
#    I recently came back to a game I have been making, but I came back to a bunch of library errors and the like. pygame.mixer didn't seem to work with the most recent version of Python (3.14) so I ended ...
#
# 31. How do you solve "Unable to import 'cx_freeze'" - E0401:import-error?
#    I am using cx_freeze for the first time, and ran the quickstart command to begin working on the package. However, upon opening the setup file in VSCodium I received the error message:
#
# Unable to ...
#
# 32. Cropping a graph in Python
#    I want to crop my graph so that it only contains the useful part of the graph. I'm meant to crop it to where the time it takes for x centered to change sign begins to become constant. I have attached ...
#
# 33. Python Multiplication of Two Arrays that May or May Not Have Same Shape
#    I have a problem where I have two arrays that can possibly have different shapes that I want to multiply together. Let's say I have two cases (I'm just using zeros right now cause all I care about is ...
#
# 34. Add context info without modifying root logger
#    I have some custom file writing library code which uses the logging module, like this:
# import logging
#
# logger = logging.getLogger(__name__)
#
# class FileWriter:
#     def write():
#         logger.info(&...
#
# 35. I get an unbalanced diagonal matrix when trying to find the eigenvalues [closed]
#    I want to find the eigenvalues of a diagonal matrix using a symmetric matrix.
# When I do this in Python, I get an unbalanced diagonal matrix. The value of [0, 0] is much larger than the other ...
#
# 36. Troubling Scope Issues Within Definition [closed]
#    I’m seeing constant UnboundLocalErrors related to an assignment having established both definition and pre-assignment prior within the function definition of the class.
# # Delete middle node
# def ...
#
# 37. pynetdicom C-GET fails when multiple transfer syntaxes are requested for compressed images
#    I am implementing a C-GET SCU using pynetdicom to retrieve CT images. When retrieving CT DICOM images with 'JPEG-LS Lossless Image Compression' transfer syntax, The SCP logs show the following error.
# ...
#
# 38. RL agent fails to converge/improve average reward in Gymnasium FlappyBird-v0 Tabular Q-Learning
#    I'm currently training a tabular Q-learning agent for Flappy Bird Gymnasium and don't know why the agent isn't learning better. Is it due to problems with discretization, the algorithm, the reward ...
#
# 39. Learning Machine Learning and AI
#    I am a fresher currently working with Python and Pandas for data handling and analysis. I am very interested in learning Machine Learning and AI, but the field feels very vast and confusing because ...
#
# 40. Why am I getting a stack trace with no exception in the message section when I run my selenium crawler
#    I hosted my selenium crawler API on render it takes data from one site and puts it in another site. When I test the app on the FastAPI interactive docs I get a stack trace with no exception so I can't ...
#
# 41. Best Way To Handle a Async Celery Task
#    I need some tips on how to best handle Celery task errors, implementing Graceful Degradation best practices. I thought about implementing try/except exception as e. But that's too simple, and I wanted ...
#
# 42. Django archive user if clicked for detail page view an error appears
#    I have this user model and in admin.py which of course is used by my client as admin page view and recently my client requested that the user/s who has been archived should not show in the active list ...
#
# 43. Get this file updated on Google Colab [closed]
#    how to get the dataset available on webiste below:
# https://www.gov.br/mdh/pt-br/acesso-a-informacao/dados-abertos/disque100/balanco-geral-2011-a-2019-populacao-lgbt/populacao-lgbt-comparativo-anual....
#
# 44. Plotly Express facets show no lines when setting x-axis range and custom tick labels
#    I have a dataframe with these columns:
#
# id_pair (pair of sensors)
# rssi_mean (detection strength)
# contact_day (day of the detection as string, e.g. 'Monday')
# study_week (week of the detection as ...
#
# 45. JP2 image metadata copying for cv2 treatment
#    I tried different methods (gdal, glymur) to extract metadata from a jp2 image to process the image with cv2 (cv2 cuts off the metadata) and later reattach the metadata for further usage in other ...
#
# 46. Can Python install packages on a shorter path on Windows?
#    I am attempting to install the grpcio package, and seeing the following error:
# (myvenv) C:\Work\Arch\Source\langchain-monitoring-demo>pip install grpcio==1.74.0
#
# Collecting grpcio==1.74.0
#   Using ...
#
# 47. Open selected file with application? Like opening a .blend file from the file explorer
#    You know how you can open a .blend file and it automatically opens it in blender? How would I do that with my own python applications? Mainly, how would I get the file path into my program on the ...
#
# 48. Mendeley Data API Issue Report [closed]
#    Dear Mendeley Data Support Team,
# I am writing to report a critical issue with the Mendeley Data public API (data.mendeley.com) that is preventing me from programmatically accessing datasets.
# Issue ...
#
# 49. ChainedAssignmentError when adding a conditional to a pandas dataframe
#    I keep getting a ChainedAssignmentError when adding a conditional to my code.  In this basic example I am checking to see if column "one" is an "e" and if so then set the "...
#
# 50. Tokenizer configuration - MLX
#    I'm currently trying to load a model on MLX. But when I'm loading the model and use the tokenizer there is the following issue:
#
# with an incorrect regex pattern: https://huggingface.co/mistralai/...
