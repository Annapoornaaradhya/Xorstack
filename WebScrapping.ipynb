# %% [markdown]
# <a href="https://colab.research.google.com/github/Annapoornaaradhya/Xorstack/blob/main/WebScrapping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
from bs4 import BeautifulSoup

url = "https://stackoverflow.com/questions/tagged/python?tab=newest"
headers = {
    "User-Agent": "Mozilla/5.0"
}
response = requests.get(url, headers=headers)
soup = BeautifulSoup(response.text, "html.parser")
questions = soup.select("div.s-post-summary h3 a.s-link")
for i, q in enumerate(questions, start=1):
    print(f"{i}. {q.get_text(strip=True)}")
# Out:
# 1. PySpark .show() fails with “Python worker exited unexpectedly” on Windows (Python 3.14)
# 2. What are the best resources for learning for a new software dev?
# 3. Pygame 2D image animations rendering in the wrong way
# 4. Can I access my Apple Music library via API from a generic Python script?
# 5. What's wrong with my Syndyne-Synchrone (comet tail) PA output?
# 6. XGBoost GPU regression fails at predict time with Check failed: dmat->Device() when training with tree_method='hist' and device='cuda'
# 7. Finding unique 1D arrays and corresponding 2D index pairs in 3D array (with numpy)
# 8. Tool to autocomplete `python -m` module calls for the Fish shell
# 9. ThreadedDepthCacheManager ignoring the limit I put at the order book
# 10. Python casting string without knowing its type [duplicate]
# 11. Is there a way to get selenium to connect to an edge browser for old IE sites?
# 12. Opencl Dot product kernel fails on specific data
# ...
